# %% [markdown]
# # 4. Design own Experiment

# %% [markdown]
# ## A. Develop a plan
#
# Come up with a plan for what you want to explore and the metrics you will use. Determine the range of options in each dimension to explore (e.g. L options in dimension 1, M options in dimension 2, and N options in dimension 3). You don't have to evaluate all L * M * N options unless you want to. Instead, think about using a linear search strategy where you hold two parameters constant and optimize the third, then switch things up, optimizing one parameter at a time in a round-robin or randomized fashion. Overall, plan to evaluate 50-100 network variations (again, automate this process).
#
#
# ROUGH PLAN:
#
# dimension 1 = number of convolution filters channels. L = 4
#
# dimension 2 = number of epochs of training. M
#
# dimension 3 = number of batch size. N = 4 (multiple of 32)
#
# - Conv. filter channels is chosen since conv is the workhorse of the NN.
# Increasing the number if filter means increaseing the number of features that will be learned
#
# - Number of epochs was proven to increase the accuracy as can be seen in task 1. Need to make sure its not overfitting
#
# - The higher the number of batch size means CPU capacity will be forced to work fully means better optimization

# %%
# torch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data.dataloader import default_collate # to reshape

import torchvision
from torchvision import datasets, transforms

# import previous notebook
import nbimporter
import Task1AE as Note1AE
import Task1FG as Note1FG

# for visualizationg
from matplotlib import pyplot as plt
import numpy as np

# for tuning and reshape for GridSearch
from skorch.dataset import Dataset
from skorch import NeuralNetClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
def get_train_test_MNIST_data():
    """
    Get MNIST dataset as X and target numpy array as y.
    Return both the train and test data. 
    """
    train_loader = Note1AE.get_loader(is_train = True)

    transform=torchvision.transforms.Compose(
                    [torchvision.transforms.ToTensor(),
                     torchvision.transforms.Normalize(
                        # normalize with mean and std
                        (0.1307,), (0.3801,)
                    )
                    ])
    #dataset
    X_train = torchvision.datasets.MNIST(
                'mnist',
                train=True,
                download=True,
                transform=transform)

    y_train = np.array([y for x, y in iter(X_train)])

    X_test= torchvision.datasets.MNIST(
                'mnist',
                train=False,
                download=True,
                transform=transform)
    y_test = np.array([y for x, y in iter(X_test)])
    
    return X_train, y_train, X_test, y_test

# %%
class NeuralNetworkDesign(nn.Module):
    """
    Another neural network for MNIST that takes parameters for 
    the number of channels
    """
    
    def __init__(self, conv1_out_channels):
        # call the parent constructor
        super(NeuralNetworkDesign, self).__init__()
        print("conv1_out_channels:",conv1_out_channels)
        
        # 1. CNN
        # input_pixel = 28 
        # out_channels = [10,..
        # output_pixel = (input_pixel) - 4 /2
        # final output = 10 X 12 X 12
        self.conv1 = nn.Conv2d(in_channels=1, 
                               out_channels=conv1_out_channels, 
                               kernel_size=5) 
        
       
        
        # input_pixel = 12
        # out_channels = [20,..
        # output_pixel = (input_pixel) - 4 /2
        # final output = 20 X 4 X 4 = 320
        self.conv2 = nn.Conv2d(in_channels=conv1_out_channels, 
                               out_channels=conv1_out_channels*2, 
                               kernel_size=5)
        self.conv2_drop = nn.Dropout2d() # default is 0.5 or half
        
        # 2. ANN
        self.in_features = conv1_out_channels * 2 * 4 * 4
        
        self.fc1 = nn.Linear(in_features=self.in_features, out_features=50)
        self.fc2 = nn.Linear(50, 10)
        self.flatten = nn.Flatten()
     

    def forward(self, x):
        # 1. first conv, max pool, relu
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        
        # 2. 2nd conv, droptout layer, max pool, relu
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        
        # 3. reshape tensor . Question: why to -1, 320. this is same as flatten
        x = x.view(-1,self.in_features)
        
        # 4. fully connected, relu
        x = F.relu(self.fc1(x))
        # x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        
        # 5. convert the output from a Linear layer
        # into a categorical probability distribution
        return F.log_softmax(x, -1)

# %%
# >>>>>> For randomoized search
class SliceDatasetX(Dataset):
    """Helper class that wraps a torch dataset to make it work with sklearn"""
    def __init__(self, dataset, collate_fn=default_collate):
        self.dataset = dataset
        self.collate_fn = collate_fn

        self._indices = list(range(len(self.dataset)))
        
    def __len__(self):
        return len(self.dataset)
        
    @property
    def shape(self):
        return len(self),
    
    def __getitem__(self, i):
        if isinstance(i, (int, np.integer)):
            Xb = self.transform(*self.dataset[i])[0]
            return Xb
        
        if isinstance(i, slice):
            i = self._indices[i]

        Xb = self.collate_fn([self.transform(*self.dataset[j])[0] for j in i])
        return Xb

# %%
# Question: this doesnt work. state keep changing
torch.manual_seed(42)
DEVICE= 'cuda' if torch.cuda.is_available() else 'cpu'

# 1. get data
X_train, y_train, X_test, y_test = get_train_test_MNIST_data()

# 2. Parameters to iterate
CONV_CHANNELS = [5, 10, 15, 20] # number of channels for 1st conv. layers
BS = [64, 128, 160, 224] # batch sizes
EPOCHS = [5, 8, 10, 12]

# 3. init Skorch NN to plug in randomized search
net = NeuralNetClassifier(
    
    # Question: Do I fill these in if Im doing randomized?
    NeuralNetworkDesign(conv1_out_channels = 10),
    batch_size=64,
    max_epochs=5,
    
    # Question: how come i dont get loss and accuracy with this:
    # optimizer=optim.SGD,
    # criterion=nn.NLLLoss,
    optimizer=optim.Adam,
    criterion=nn.CrossEntropyLoss,
    iterator_train__num_workers=4,
    device=DEVICE
)

net.fit(X_train, y_train)
# Out:
# conv1_out_channels: 10

# %% [markdown]
# ## B. Predict the results
#
# Before starting your evaluation, come up with a hypothesis for how you expect the network to behave along each dimension. Include these hypotheses in your report and then discuss whether the evaluation supported the hypothesis.

# %% [markdown]
# ## TODO:
# come up with a hypothesis for how you expect the network to behave along each dimension.
# discuss whether the evaluation supported the hypothesis.

# %%
# Question: This method returns the mean accuracy on the given data and labels for classifiers
# what score is this ? correct / total?
net.score(X_test, y_test)
# Out:
# 0.9823

# %% [markdown]
# ## C. Execute your plan
#
# Run the evaluation and report on the results.

# %%
# 1. convert data to numpy
X_slicable =  SliceDatasetX(X_train)

# 2. set params
params = {
    'module__conv1_out_channels': CONV_CHANNELS,
    'batch_size': BS,
    'max_epochs': EPOCHS,
}


# 3. Create randomized search object
rs = RandomizedSearchCV(
                  net,
                  params,
                  refit=False,
                  cv=3,
                  scoring='accuracy',
                  verbose=2,
                  n_iter=50,
                  random_state=42)


# 4. run and evaluate
rs.fit(X_slicable, y_train)
print("best score: {:.3f}, best params: {}".format(rs.best_score_, rs.best_params_))
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5952       0.9515        0.1491  3.3847
#       2        0.2425       0.9630        0.1098  3.2699
#       3        0.1931       0.9689        0.0971  3.2749
#       4        0.1820       0.9701        0.0932  3.1324
#       5        0.1664       0.9714        0.0928  3.1815
#       6        0.1572       0.9695        0.0956  3.2179
#       7        0.1591       0.9712        0.0893  3.1792
#       8        0.1476       0.9758        0.0775  3.1682
# [CV] END batch_size=224, max_epochs=8, module__conv1_out_channels=5; total time=  28.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5556       0.9555        0.1486  3.2547
#       2        0.2798       0.9621        0.1279  3.2791
#       3        0.2274       0.9725        0.1015  3.2178
#       4        0.2163       0.9726        0.0931  3.2278
#       5        0.1794       0.9725        0.0905  3.2197
#       6        0.1784       0.9768        0.0794  3.2726
#       7        0.1740       0.9748        0.0824  3.2042
#       8        0.1672       0.9741        0.0871  3.2380
# [CV] END batch_size=224, max_epochs=8, module__conv1_out_channels=5; total time=  28.5s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5782       0.9561        0.1526  3.1879
#       2        0.2648       0.9671        0.1069  3.2341
#       3        0.2111       0.9695        0.1043  3.2006
#       4        0.1983       0.9741        0.0875  3.1728
#       5        0.1747       0.9704        0.0982  3.1033
#       6        0.1727       0.9744        0.0794  3.2361
#       7        0.1693       0.9735        0.0853  3.0907
#       8        0.1623       0.9770        0.0786  3.0595
# [CV] END batch_size=224, max_epochs=8, module__conv1_out_channels=5; total time=  27.9s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.3296       0.9083        0.3081  4.3161
#       2        0.7791       0.9436        0.1882  4.3152
#       3        0.7477       0.9543        0.1532  4.1599
#       4        0.7232       0.9540        0.1570  4.2894
#       5        0.7083       0.9514        0.1511  4.3054
#       6        0.7092       0.9597        0.1465  4.4292
#       7        0.7028       0.9584        0.1461  4.5215
#       8        0.6969       0.9590        0.1401  4.4818
#       9        0.7070       0.9635        0.1281  4.3535
#      10        0.6877       0.9613        0.1330  4.3746
# [CV] END batch_size=224, max_epochs=10, module__conv1_out_channels=15; total time=  46.4s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.5711       0.8498        0.6047  4.4896
#       2        1.3473       0.8991        0.4034  4.3292
#       3        1.3083       0.8985        0.4041  4.3686
#       4        1.3067       0.9071        0.3660  4.4052
#       5        1.2886       0.9130        0.3831  4.4063
#       6        1.2787       0.9157        0.3486  4.2735
#       7        1.2807       0.9028        0.3606  4.2780
#       8        1.2829       0.9275        0.3150  4.2918
#       9        1.2676       0.9181        0.3166  4.3279
#      10        1.2717       0.9339        0.2761  4.3342
# [CV] END batch_size=224, max_epochs=10, module__conv1_out_channels=15; total time=  46.4s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.1429       0.9195        0.3116  4.3562
#       2        0.8274       0.9351        0.2537  4.3084
#       3        0.7714       0.9510        0.2168  4.3318
#       4        0.7504       0.9633        0.1571  4.2901
#       5        0.5859       0.9603        0.1526  4.3465
#       6        0.4795       0.9611        0.1465  4.3121
#       7        0.4563       0.9644        0.1259  4.2811
#       8        0.4413       0.9694        0.1351  4.3015
#       9        0.4427       0.9681        0.1170  4.3085
#      10        0.4493       0.9637        0.1361  4.3396
# [CV] END batch_size=224, max_epochs=10, module__conv1_out_channels=15; total time=  46.1s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.9098       0.9000        0.3299  4.2196
#       2        0.4597       0.9231        0.2349  4.2171
#       3        0.3637       0.9556        0.1406  4.1445
#       4        0.3348       0.9621        0.1256  4.2074
#       5        0.3138       0.9565        0.1410  4.2769
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=5; total time=  23.9s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5587       0.9429        0.1908  4.2243
#       2        0.3536       0.9536        0.1518  4.2347
#       3        0.3310       0.9454        0.1727  4.1058
#       4        0.3028       0.9635        0.1204  4.0824
#       5        0.2919       0.9614        0.1354  4.0889
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=5; total time=  23.6s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4782       0.9447        0.1822  4.0795
#       2        0.2858       0.9630        0.1221  4.1570
#       3        0.2637       0.9576        0.1467  4.1951
#       4        0.2529       0.9601        0.1442  4.1910
#       5        0.2442       0.9601        0.1345  4.0410
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=5; total time=  23.5s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5925       0.9476        0.1715  3.1827
#       2        0.2821       0.9569        0.1404  3.1796
#       3        0.2381       0.9679        0.1065  3.2261
#       4        0.2176       0.9670        0.1052  3.1692
#       5        0.1966       0.9715        0.0920  3.2793
#       6        0.1888       0.9684        0.0997  3.1594
#       7        0.1818       0.9722        0.0966  3.1882
#       8        0.1874       0.9700        0.1008  3.2742
#       9        0.1729       0.9722        0.0883  3.2929
#      10        0.1667       0.9710        0.0939  3.3107
#      11        0.1652       0.9705        0.0910  3.2386
#      12        0.1638       0.9722        0.0887  3.2800
# [CV] END batch_size=160, max_epochs=12, module__conv1_out_channels=5; total time=  41.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5470       0.9574        0.1503  3.2835
#       2        0.2669       0.9704        0.0988  3.2853
#       3        0.2206       0.9715        0.1015  3.3834
#       4        0.1963       0.9748        0.0801  3.2875
#       5        0.1884       0.9770        0.0822  3.3664
#       6        0.1861       0.9720        0.0879  3.6890
#       7        0.1736       0.9751        0.0845  3.4767
#       8        0.1771       0.9778        0.0757  3.6210
#       9        0.1838       0.9764        0.0826  3.4368
#      10        0.1710       0.9775        0.0742  3.3307
#      11        0.1556       0.9774        0.0824  3.3947
#      12        0.1635       0.9714        0.0919  3.3205
# [CV] END batch_size=160, max_epochs=12, module__conv1_out_channels=5; total time=  43.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6430       0.9510        0.1647  3.1927
#       2        0.3095       0.9617        0.1335  3.2662
#       3        0.2607       0.9683        0.1097  3.2430
#       4        0.2310       0.9702        0.1045  3.2821
#       5        0.2150       0.9660        0.1107  3.3188
#       6        0.2032       0.9685        0.1068  3.4003
#       7        0.1953       0.9744        0.0928  3.4184
#       8        0.1925       0.9698        0.1049  3.3564
#       9        0.1796       0.9750        0.0990  3.3571
#      10        0.1824       0.9764        0.0892  3.2118
#      11        0.1755       0.9744        0.0886  3.2883
#      12        0.1703       0.9770        0.0811  3.3231
# [CV] END batch_size=160, max_epochs=12, module__conv1_out_channels=5; total time=  42.3s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4950       0.9509        0.1583  4.8791
#       2        0.2585       0.9516        0.1870  4.9697
#       3        0.2256       0.9460        0.1808  4.8107
#       4        0.2076       0.9615        0.1351  4.8567
#       5        0.1903       0.9689        0.1177  4.8329
#       6        0.1830       0.9739        0.0955  4.6450
#       7        0.1835       0.9659        0.1206  4.8021
#       8        0.1921       0.9769        0.0864  4.7393
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=10; total time=  41.5s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4237       0.9549        0.1544  4.7182
#       2        0.2450       0.9646        0.1284  4.6345
#       3        0.2129       0.9683        0.1084  4.7969
#       4        0.2052       0.9689        0.1057  4.7222
#       5        0.2040       0.9696        0.1082  4.6818
#       6        0.2029       0.9685        0.1113  4.7261
#       7        0.1950       0.9659        0.1187  4.7991
#       8        0.1950       0.9701        0.1059  4.6425
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=10; total time=  40.7s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5664       0.9460        0.1910  4.6773
#       2        0.3305       0.9289        0.2245  4.7717
#       3        0.2768       0.9643        0.1283  4.6463
#       4        0.2793       0.9666        0.1215  4.6403
#       5        0.2513       0.9696        0.1107  4.5813
#       6        0.2500       0.9644        0.1303  4.6507
#       7        0.2388       0.9589        0.1437  4.7399
#       8        0.2344       0.9676        0.1200  4.8403
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=10; total time=  40.5s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5713       0.9476        0.1628  3.2346
#       2        0.2795       0.9631        0.1360  3.2353
#       3        0.2332       0.9627        0.1162  3.3090
#       4        0.2246       0.9670        0.1113  3.1266
#       5        0.2023       0.9692        0.1021  3.1615
#       6        0.1971       0.9715        0.1021  3.2599
#       7        0.1923       0.9657        0.1159  3.2155
#       8        0.1892       0.9712        0.0924  3.3291
# [CV] END batch_size=160, max_epochs=8, module__conv1_out_channels=5; total time=  28.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5769       0.9546        0.1592  3.3374
#       2        0.2799       0.9653        0.1158  3.3442
#       3        0.2428       0.9691        0.1101  3.3037
#       4        0.2074       0.9692        0.1016  3.3133
#       5        0.2046       0.9704        0.0996  3.3770
#       6        0.1940       0.9715        0.0945  3.1744
#       7        0.1963       0.9730        0.0896  3.2423
#       8        0.1930       0.9711        0.0928  3.3475
# [CV] END batch_size=160, max_epochs=8, module__conv1_out_channels=5; total time=  29.1s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5087       0.9523        0.1563  3.3590
#       2        0.2663       0.9600        0.1283  3.3334
#       3        0.2260       0.9692        0.1057  3.3607
#       4        0.2060       0.9705        0.1052  3.2792
#       5        0.1925       0.9718        0.0998  3.2790
#       6        0.1755       0.9731        0.0905  3.3239
#       7        0.1788       0.9695        0.1009  3.4453
#       8        0.1712       0.9756        0.0883  3.4110
# [CV] END batch_size=160, max_epochs=8, module__conv1_out_channels=5; total time=  29.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5702       0.9499        0.1671  3.7268
#       2        0.3076       0.9595        0.1323  3.6179
#       3        0.2498       0.9650        0.1202  3.6690
#       4        0.2324       0.9643        0.1232  3.5133
#       5        0.2170       0.9649        0.1204  3.7613
# [CV] END batch_size=128, max_epochs=5, module__conv1_out_channels=5; total time=  20.9s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5033       0.9537        0.1572  3.7702
#       2        0.2633       0.9627        0.1259  3.7716
#       3        0.2296       0.9704        0.1046  3.6851
#       4        0.2012       0.9721        0.0961  3.5129
#       5        0.1909       0.9734        0.0986  3.5169
# [CV] END batch_size=128, max_epochs=5, module__conv1_out_channels=5; total time=  20.9s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5374       0.9610        0.1411  3.6852
#       2        0.2669       0.9637        0.1256  3.6286
#       3        0.2398       0.9624        0.1280  3.6622
#       4        0.1967       0.9726        0.1061  3.6234
#       5        0.2000       0.9705        0.0979  3.5670
# [CV] END batch_size=128, max_epochs=5, module__conv1_out_channels=5; total time=  20.9s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6788       0.9265        0.2281  3.9154
#       2        0.3853       0.9465        0.1657  4.0118
#       3        0.3404       0.9473        0.1623  3.9799
#       4        0.3242       0.9559        0.1512  3.8950
#       5        0.3275       0.9551        0.1478  3.7507
#       6        0.3273       0.9575        0.1429  3.7563
#       7        0.3078       0.9636        0.1277  3.7391
#       8        0.3020       0.9585        0.1365  3.9638
#       9        0.3133       0.9559        0.1449  4.0260
#      10        0.3022       0.9551        0.1458  4.0696
#      11        0.2996       0.9650        0.1218  4.0019
#      12        0.3041       0.9580        0.1504  3.7519
# [CV] END batch_size=64, max_epochs=12, module__conv1_out_channels=5; total time=  49.6s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5599       0.9533        0.1555  3.7959
#       2        0.3235       0.9535        0.1513  3.9895
#       3        0.2818       0.9620        0.1245  3.9537
#       4        0.2748       0.9637        0.1219  3.8989
#       5        0.2737       0.9673        0.1094  3.8395
#       6        0.2731       0.9676        0.1133  3.8469
#       7        0.2663       0.9584        0.1531  3.6878
#       8        0.2663       0.9645        0.1226  3.7389
#       9        0.2618       0.9660        0.1150  3.6527
#      10        0.2656       0.9625        0.1268  3.7797
#      11        0.2529       0.9674        0.1172  4.0780
#      12        0.2591       0.9660        0.1197  3.7959
# [CV] END batch_size=64, max_epochs=12, module__conv1_out_channels=5; total time=  48.7s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5290       0.9445        0.1896  3.7232
#       2        0.3028       0.9577        0.1599  3.8164
#       3        0.2824       0.9546        0.1527  3.6993
#       4        0.2605       0.9611        0.1398  3.7843
#       5        0.2533       0.9624        0.1539  3.8733
#       6        0.2466       0.9699        0.1101  3.8389
#       7        0.2459       0.9607        0.1419  4.0195
#       8        0.2433       0.9666        0.1184  4.0336
#       9        0.2331       0.9611        0.1397  3.9536
#      10        0.2436       0.9690        0.1121  3.7986
#      11        0.2310       0.9626        0.1363  3.8430
#      12        0.2404       0.9694        0.1164  3.8762
# [CV] END batch_size=64, max_epochs=12, module__conv1_out_channels=5; total time=  48.9s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4916       0.9531        0.1533  4.0514
#       2        0.2247       0.9702        0.1087  4.2880
#       3        0.1802       0.9726        0.0936  4.5157
#       4        0.1585       0.9764        0.0831  4.2514
#       5        0.1526       0.9721        0.1025  4.1178
#       6        0.1451       0.9750        0.0890  4.1357
#       7        0.1446       0.9758        0.0919  4.2287
#       8        0.1413       0.9740        0.0876  4.1853
#       9        0.1391       0.9760        0.0850  4.3987
#      10        0.1330       0.9738        0.0893  4.2610
# [CV] END batch_size=128, max_epochs=10, module__conv1_out_channels=10; total time=  45.2s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4464       0.9630        0.1229  4.2587
#       2        0.2210       0.9719        0.0988  4.1676
#       3        0.1878       0.9724        0.0944  4.3124
#       4        0.1769       0.9755        0.0902  4.2826
#       5        0.1712       0.9765        0.0828  4.2025
#       6        0.1519       0.9755        0.0838  4.1181
#       7        0.1443       0.9776        0.0772  4.2277
#       8        0.1515       0.9749        0.0832  4.0799
#       9        0.1490       0.9770        0.0851  4.1347
#      10        0.1416       0.9805        0.0728  4.3587
# [CV] END batch_size=128, max_epochs=10, module__conv1_out_channels=10; total time=  45.0s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6217       0.9250        0.2648  4.2794
#       2        0.3473       0.9623        0.1286  4.3060
#       3        0.2896       0.9653        0.1263  4.3114
#       4        0.2464       0.9688        0.1051  4.1946
#       5        0.2371       0.9722        0.0948  4.1913
#       6        0.2121       0.9746        0.0926  4.1925
#       7        0.1990       0.9686        0.1053  4.1672
#       8        0.1966       0.9755        0.0874  4.2439
#       9        0.1838       0.9714        0.1069  4.3032
#      10        0.1829       0.9698        0.1058  4.4513
# [CV] END batch_size=128, max_epochs=10, module__conv1_out_channels=10; total time=  45.6s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7079       0.9493        0.1553  3.9225
#       2        0.2879       0.9666        0.1042  3.8266
#       3        0.2348       0.9631        0.1081  3.5902
#       4        0.2062       0.9722        0.0836  3.7005
#       5        0.1852       0.9712        0.0868  3.7679
#       6        0.1771       0.9694        0.1021  3.7678
#       7        0.1724       0.9715        0.0913  3.7126
#       8        0.1617       0.9766        0.0762  3.7601
#       9        0.1566       0.9720        0.0895  3.5915
#      10        0.1655       0.9721        0.0886  3.5949
#      11        0.1501       0.9730        0.0865  3.5741
#      12        0.1535       0.9772        0.0731  3.8438
# [CV] END batch_size=224, max_epochs=12, module__conv1_out_channels=10; total time=  47.4s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6451       0.9493        0.1653  3.8141
#       2        0.2835       0.9589        0.1324  4.0384
#       3        0.2333       0.9698        0.1060  3.7864
#       4        0.2113       0.9671        0.1140  3.6102
#       5        0.1948       0.9699        0.0978  3.7350
#       6        0.1911       0.9716        0.0953  3.7823
#       7        0.1808       0.9692        0.1067  3.6848
#       8        0.1730       0.9734        0.0896  3.7696
#       9        0.1666       0.9760        0.0851  3.8890
#      10        0.1597       0.9736        0.0878  3.7018
#      11        0.1608       0.9714        0.0983  3.8845
#      12        0.1583       0.9776        0.0816  3.9022
# [CV] END batch_size=224, max_epochs=12, module__conv1_out_channels=10; total time=  48.4s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4781       0.9680        0.1106  3.8479
#       2        0.1924       0.9734        0.0912  3.7542
#       3        0.1564       0.9742        0.0892  3.5949
#       4        0.1387       0.9772        0.0792  3.5608
#       5        0.1359       0.9780        0.0762  3.5692
#       6        0.1160       0.9820        0.0661  3.5479
#       7        0.1129       0.9811        0.0663  3.5686
#       8        0.1208       0.9795        0.0793  3.5462
#       9        0.1151       0.9780        0.0747  3.5509
#      10        0.1086       0.9790        0.0689  3.5569
#      11        0.0995       0.9782        0.0759  3.5458
#      12        0.1138       0.9816        0.0666  3.7831
# [CV] END batch_size=224, max_epochs=12, module__conv1_out_channels=10; total time=  46.2s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7368       0.9327        0.2016  3.0455
#       2        0.3603       0.9575        0.1371  3.0171
#       3        0.2712       0.9595        0.1334  3.1238
#       4        0.2543       0.9651        0.1225  3.1083
#       5        0.2184       0.9656        0.1087  3.1276
#       6        0.2104       0.9694        0.1036  3.0742
#       7        0.1986       0.9738        0.0875  2.9807
#       8        0.1898       0.9735        0.0865  2.9874
#       9        0.1830       0.9724        0.0890  2.9857
#      10        0.1793       0.9741        0.0883  3.1367
# [CV] END batch_size=224, max_epochs=10, module__conv1_out_channels=5; total time=  33.2s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5666       0.9559        0.1449  3.0100
#       2        0.2571       0.9680        0.1080  3.0592
#       3        0.2100       0.9676        0.1017  2.9936
#       4        0.1811       0.9725        0.0930  3.0692
#       5        0.1677       0.9758        0.0838  3.2297
#       6        0.1540       0.9758        0.0774  3.1151
#       7        0.1568       0.9755        0.0919  3.1468
#       8        0.1539       0.9740        0.0935  3.2107
#       9        0.1527       0.9786        0.0798  3.1638
#      10        0.1352       0.9755        0.0864  3.2840
# [CV] END batch_size=224, max_epochs=10, module__conv1_out_channels=5; total time=  33.9s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6172       0.9545        0.1584  3.2301
#       2        0.2799       0.9666        0.1177  3.2868
#       3        0.2181       0.9704        0.1044  3.3468
#       4        0.1968       0.9728        0.1000  3.3601
#       5        0.1906       0.9718        0.0945  3.4517
#       6        0.1690       0.9724        0.0969  3.1307
#       7        0.1649       0.9711        0.0926  3.2472
#       8        0.1618       0.9742        0.0869  3.4706
#       9        0.1464       0.9749        0.0842  3.3722
#      10        0.1502       0.9756        0.0821  3.2407
# [CV] END batch_size=224, max_epochs=10, module__conv1_out_channels=5; total time=  35.7s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6136       0.9329        0.2156  4.5534
#       2        0.3268       0.9463        0.1691  5.0153
#       3        0.2985       0.9593        0.1312  5.0234
#       4        0.2789       0.9561        0.1488  4.7308
#       5        0.2762       0.9604        0.1352  4.9302
#       6        0.2676       0.9546        0.1584  4.8845
#       7        0.2510       0.9654        0.1187  4.9547
#       8        0.2535       0.9667        0.1149  4.9408
#       9        0.2361       0.9661        0.1218  4.9227
#      10        0.2300       0.9669        0.1185  4.5306
# [CV] END batch_size=64, max_epochs=10, module__conv1_out_channels=10; total time=  51.4s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4082       0.9570        0.1386  4.4824
#       2        0.2270       0.9627        0.1316  4.5656
#       3        0.2047       0.9729        0.1038  4.7597
#       4        0.2014       0.9734        0.0970  4.5561
#       5        0.1791       0.9739        0.0953  4.6653
#       6        0.1758       0.9645        0.1302  4.7728
#       7        0.1855       0.9775        0.0848  4.7326
#       8        0.1730       0.9718        0.1013  4.6350
#       9        0.1719       0.9685        0.1094  4.6285
#      10        0.1801       0.9755        0.0920  4.7739
# [CV] END batch_size=64, max_epochs=10, module__conv1_out_channels=10; total time=  49.5s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4679       0.9425        0.1887  4.6942
#       2        0.2613       0.9569        0.1428  4.6772
#       3        0.2132       0.9611        0.1284  4.8983
#       4        0.2075       0.9645        0.1246  4.8097
#       5        0.1899       0.9621        0.1356  4.7746
#       6        0.1845       0.9635        0.1308  4.5207
#       7        0.1923       0.9700        0.1077  4.7233
#       8        0.1813       0.9711        0.1037  4.9476
#       9        0.1748       0.9684        0.1136  4.6598
#      10        0.1794       0.9708        0.1188  4.7574
# [CV] END batch_size=64, max_epochs=10, module__conv1_out_channels=10; total time=  50.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6299       0.9374        0.1949  3.2661
#       2        0.2956       0.9633        0.1248  3.2514
#       3        0.2558       0.9670        0.1072  3.3551
#       4        0.2340       0.9714        0.0915  3.2943
#       5        0.2105       0.9718        0.0927  3.2334
#       6        0.2091       0.9706        0.0970  3.1165
#       7        0.1999       0.9752        0.0893  3.1605
#       8        0.2002       0.9718        0.0863  3.1046
#       9        0.1863       0.9762        0.0782  3.1742
#      10        0.1861       0.9748        0.0821  3.2425
# [CV] END batch_size=160, max_epochs=10, module__conv1_out_channels=5; total time=  34.8s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4699       0.9551        0.1460  3.2234
#       2        0.2289       0.9656        0.1152  3.1245
#       3        0.1977       0.9720        0.0936  3.2771
#       4        0.1881       0.9761        0.0842  3.3555
#       5        0.1738       0.9769        0.0750  3.2121
#       6        0.1590       0.9764        0.0810  3.1800
#       7        0.1574       0.9765        0.0816  3.1443
#       8        0.1559       0.9758        0.0839  3.2909
#       9        0.1499       0.9809        0.0699  3.4542
#      10        0.1457       0.9790        0.0708  3.4671
# [CV] END batch_size=160, max_epochs=10, module__conv1_out_channels=5; total time=  35.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5875       0.9491        0.1733  3.5842
#       2        0.2713       0.9665        0.1226  3.5391
#       3        0.2251       0.9685        0.1094  3.5885
#       4        0.2106       0.9688        0.1064  3.2594
#       5        0.1903       0.9730        0.0940  3.2282
#       6        0.1849       0.9691        0.1103  3.2329
#       7        0.1912       0.9756        0.0895  3.2726
#       8        0.1803       0.9759        0.0873  3.2562
#       9        0.1740       0.9731        0.0914  3.3215
#      10        0.1691       0.9681        0.1119  3.3201
# [CV] END batch_size=160, max_epochs=10, module__conv1_out_channels=5; total time=  36.2s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4371       0.9517        0.1514  4.9139
#       2        0.2450       0.9614        0.1286  5.1371
#       3        0.2153       0.9684        0.1068  4.9036
#       4        0.1962       0.9679        0.1126  4.5929
#       5        0.1979       0.9690        0.1119  5.0255
#       6        0.1916       0.9677        0.1140  4.6883
#       7        0.1893       0.9744        0.1034  4.4428
#       8        0.1815       0.9710        0.1068  4.4079
#       9        0.1805       0.9615        0.1514  4.6869
#      10        0.2024       0.9686        0.1176  4.8454
#      11        0.1774       0.9666        0.1238  4.5239
#      12        0.1830       0.9744        0.0932  4.8744
# [CV] END batch_size=64, max_epochs=12, module__conv1_out_channels=10; total time=  60.0s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4351       0.9415        0.2283  4.6060
#       2        0.2454       0.9629        0.1209  4.5255
#       3        0.2173       0.9688        0.1035  4.6505
#       4        0.1970       0.9620        0.1501  4.6248
#       5        0.2074       0.9599        0.1360  4.6901
#       6        0.1982       0.9650        0.1323  4.6371
#       7        0.1850       0.9663        0.1319  4.5490
#       8        0.1832       0.9679        0.1167  4.5657
#       9        0.1926       0.9732        0.1102  4.4820
#      10        0.1812       0.9629        0.1374  4.4219
#      11        0.1814       0.9726        0.1064  4.4359
#      12        0.1712       0.9728        0.1003  4.3914
# [CV] END batch_size=64, max_epochs=12, module__conv1_out_channels=10; total time=  57.4s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4101       0.9523        0.1600  4.3360
#       2        0.2346       0.9676        0.1116  4.6169
#       3        0.2084       0.9605        0.1537  4.6555
#       4        0.1954       0.9625        0.1301  4.5670
#       5        0.1939       0.9647        0.1296  4.5144
#       6        0.1806       0.9669        0.1156  4.5295
#       7        0.1788       0.9684        0.1087  4.5724
#       8        0.1635       0.9610        0.1457  4.6670
#       9        0.1781       0.9728        0.1013  4.3545
#      10        0.1625       0.9758        0.0940  4.3545
#      11        0.1664       0.9724        0.1106  4.3535
#      12        0.1692       0.9745        0.0988  4.3673
# [CV] END batch_size=64, max_epochs=12, module__conv1_out_channels=10; total time=  56.7s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.8220       0.9375        0.1934  4.2844
#       2        0.5231       0.9459        0.1703  4.2693
#       3        0.4890       0.9581        0.1327  4.2444
#       4        0.4149       0.9626        0.1197  4.3611
#       5        0.3094       0.9640        0.1196  4.2847
# [CV] END batch_size=160, max_epochs=5, module__conv1_out_channels=15; total time=  24.2s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5647       0.9544        0.1485  4.4687
#       2        0.2673       0.9676        0.1065  4.3918
#       3        0.2196       0.9734        0.0861  4.4031
#       4        0.2046       0.9726        0.0897  4.3385
#       5        0.1766       0.9700        0.0984  4.3106
# [CV] END batch_size=160, max_epochs=5, module__conv1_out_channels=15; total time=  24.7s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4669       0.9623        0.1282  4.3554
#       2        0.2089       0.9636        0.1445  4.3020
#       3        0.1774       0.9762        0.0861  4.5372
#       4        0.1639       0.9771        0.0831  4.4115
#       5        0.1495       0.9805        0.0758  4.3926
# [CV] END batch_size=160, max_epochs=5, module__conv1_out_channels=15; total time=  24.8s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        1.5532       0.8742        0.4984  4.3053
#       2        1.3207       0.9038        0.4056  4.4905
#       3        1.2762       0.9050        0.3863  4.3974
#       4        1.2722       0.9304        0.2977  4.3089
#       5        1.2644       0.9360        0.3047  4.2571
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=15; total time=  24.6s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4602       0.9721        0.0960  4.2923
#       2        0.1813       0.9760        0.0808  4.2709
#       3        0.1492       0.9776        0.0797  4.2171
#       4        0.1288       0.9780        0.0784  4.3308
#       5        0.1301       0.9782        0.0819  4.3141
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=15; total time=  24.2s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.3964       0.9716        0.1006  4.4188
#       2        0.1659       0.9775        0.0759  4.2253
#       3        0.1280       0.9801        0.0660  4.2319
#       4        0.1283       0.9814        0.0606  4.1621
#       5        0.1072       0.9831        0.0622  4.2708
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=15; total time=  24.1s
# conv1_out_channels: 20
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.8405       0.9167        0.2802  6.4684
#       2        0.5560       0.9394        0.2060  6.3359
#       3        0.3851       0.9520        0.1532  6.6397
#       4        0.3107       0.9501        0.1706  6.4477
#       5        0.2608       0.9585        0.1375  6.2667
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=20; total time=  35.4s
# conv1_out_channels: 20
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6433       0.9371        0.2029  6.1820
#       2        0.3461       0.9580        0.1397  6.1517
#       3        0.2931       0.9629        0.1277  6.1017
#       4        0.2480       0.9689        0.1096  6.1865
#       5        0.2174       0.9686        0.1011  6.1090
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=20; total time=  33.9s
# conv1_out_channels: 20
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.8355       0.9406        0.2150  6.1959
#       2        0.5832       0.9296        0.2518  6.1254
#       3        0.4514       0.9321        0.2238  6.1329
#       4        0.3765       0.9493        0.1658  6.2279
#       5        0.3148       0.9556        0.1520  6.1708
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=20; total time=  34.0s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7177       0.9426        0.1898  4.1623
#       2        0.3512       0.9626        0.1251  4.1499
#       3        0.2899       0.9675        0.1125  4.1629
#       4        0.2644       0.9656        0.1249  4.2255
#       5        0.2539       0.9686        0.1123  4.3172
# [CV] END batch_size=128, max_epochs=5, module__conv1_out_channels=10; total time=  23.9s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5077       0.9534        0.1597  4.3478
#       2        0.2512       0.9661        0.1163  4.1724
#       3        0.2121       0.9715        0.1031  4.2589
#       4        0.2009       0.9711        0.1026  4.2382
#       5        0.1794       0.9760        0.0898  4.2295
# [CV] END batch_size=128, max_epochs=5, module__conv1_out_channels=10; total time=  24.1s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4355       0.9566        0.1426  4.2250
#       2        0.1986       0.9675        0.1112  4.3738
#       3        0.1791       0.9754        0.0815  4.2000
#       4        0.1599       0.9781        0.0784  4.1975
#       5        0.1490       0.9792        0.0724  4.1286
# [CV] END batch_size=128, max_epochs=5, module__conv1_out_channels=10; total time=  23.9s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4970       0.9576        0.1325  3.8033
#       2        0.2034       0.9684        0.1031  3.6591
#       3        0.1685       0.9680        0.1025  3.6602
#       4        0.1458       0.9756        0.0805  3.7396
#       5        0.1363       0.9774        0.0734  3.7387
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=10; total time=  21.4s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4503       0.9629        0.1311  3.8195
#       2        0.2055       0.9677        0.1074  3.8171
#       3        0.1660       0.9749        0.0896  3.6499
#       4        0.1470       0.9766        0.0836  3.8698
#       5        0.1376       0.9781        0.0755  3.6720
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=10; total time=  21.5s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7184       0.9439        0.1785  3.6857
#       2        0.3323       0.9673        0.1104  3.7655
#       3        0.2778       0.9669        0.1072  3.6353
#       4        0.2472       0.9748        0.0854  3.6169
#       5        0.2275       0.9729        0.0932  3.6006
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=10; total time=  21.0s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7025       0.9377        0.1969  3.8719
#       2        0.4278       0.9454        0.1797  3.7528
#       3        0.3824       0.9353        0.2171  3.8201
#       4        0.3736       0.9329        0.2665  4.0490
#       5        0.3574       0.9346        0.2141  3.7063
#       6        0.3460       0.9510        0.1744  3.8385
#       7        0.3384       0.9590        0.1386  3.7314
#       8        0.3482       0.9404        0.2015  3.9883
#       9        0.3299       0.9560        0.1509  3.8181
#      10        0.3377       0.9397        0.2149  3.9837
# [CV] END batch_size=64, max_epochs=10, module__conv1_out_channels=5; total time=  41.3s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4740       0.9534        0.1570  4.1848
#       2        0.2732       0.9546        0.1467  4.1111
#       3        0.2385       0.9633        0.1195  3.8895
#       4        0.2328       0.9554        0.1606  3.7224
#       5        0.2182       0.9631        0.1297  3.7241
#       6        0.2183       0.9596        0.1364  3.8152
#       7        0.2105       0.9657        0.1417  3.7822
#       8        0.2143       0.9613        0.1365  3.7838
#       9        0.2214       0.9659        0.1267  3.7254
#      10        0.2061       0.9734        0.0995  3.9096
# [CV] END batch_size=64, max_epochs=10, module__conv1_out_channels=5; total time=  41.4s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4786       0.9095        0.3031  3.7971
#       2        0.2783       0.9557        0.1599  3.7463
#       3        0.2485       0.9607        0.1462  3.7202
#       4        0.2501       0.9484        0.1786  3.7216
#       5        0.2307       0.9675        0.1201  3.6901
#       6        0.2283       0.9609        0.1375  3.7970
#       7        0.2290       0.9688        0.1180  3.8441
#       8        0.2191       0.9673        0.1229  3.7533
#       9        0.2272       0.9688        0.1140  3.7416
#      10        0.2142       0.9695        0.1098  3.6493
# [CV] END batch_size=64, max_epochs=10, module__conv1_out_channels=5; total time=  40.2s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6635       0.9176        0.2821  5.2177
#       2        0.3678       0.9527        0.1477  5.1330
#       3        0.3347       0.9517        0.1620  5.1530
#       4        0.2990       0.9545        0.1451  5.3179
#       5        0.2723       0.9585        0.1411  5.5470
#       6        0.2589       0.9629        0.1296  5.4910
#       7        0.2473       0.9683        0.1109  5.2311
#       8        0.2274       0.9650        0.1134  5.1981
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=15; total time=  45.2s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.3700       0.9604        0.1241  5.1038
#       2        0.2049       0.9689        0.1084  5.0921
#       3        0.1788       0.9721        0.0962  5.0636
#       4        0.1782       0.9692        0.1218  5.0825
#       5        0.1743       0.9745        0.0978  5.0822
#       6        0.1666       0.9711        0.1125  5.0817
#       7        0.1652       0.9751        0.0940  5.2380
#       8        0.1634       0.9751        0.1032  5.2890
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=15; total time=  44.0s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4450       0.9603        0.1376  5.3181
#       2        0.2364       0.9583        0.1497  5.1032
#       3        0.2146       0.9664        0.1253  5.1178
#       4        0.1990       0.9673        0.1132  5.3453
#       5        0.1863       0.9698        0.1032  5.4223
#       6        0.1876       0.9680        0.1198  5.3272
#       7        0.1860       0.9680        0.1156  5.1902
#       8        0.1791       0.9692        0.1138  5.3023
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=15; total time=  45.2s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4176       0.9655        0.1119  3.8051
#       2        0.1711       0.9732        0.0913  3.8270
#       3        0.1446       0.9786        0.0680  3.8204
#       4        0.1358       0.9755        0.0772  3.7159
#       5        0.1245       0.9805        0.0638  3.6626
# [CV] END batch_size=160, max_epochs=5, module__conv1_out_channels=10; total time=  21.5s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5483       0.9497        0.1656  3.5250
#       2        0.2735       0.9674        0.1116  3.6546
#       3        0.2326       0.9647        0.1241  3.6066
#       4        0.2123       0.9690        0.1037  3.5458
#       5        0.1955       0.9708        0.0891  3.5325
# [CV] END batch_size=160, max_epochs=5, module__conv1_out_channels=10; total time=  20.6s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4589       0.9619        0.1242  3.5162
#       2        0.1972       0.9704        0.0957  3.5694
#       3        0.1601       0.9762        0.0827  3.5374
#       4        0.1499       0.9756        0.0871  3.5488
#       5        0.1431       0.9761        0.0834  3.6427
# [CV] END batch_size=160, max_epochs=5, module__conv1_out_channels=10; total time=  20.5s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6107       0.9051        0.2821  4.2667
#       2        0.3755       0.9425        0.1796  4.2017
#       3        0.3210       0.9539        0.1508  3.8380
#       4        0.3006       0.9450        0.1902  3.9755
#       5        0.2897       0.9425        0.1971  3.8749
#       6        0.2746       0.9607        0.1271  3.9778
#       7        0.2734       0.9591        0.1381  4.0816
#       8        0.2670       0.9590        0.1409  4.4795
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=5; total time=  35.5s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5896       0.9346        0.2198  4.1992
#       2        0.3496       0.9505        0.1582  4.1114
#       3        0.3072       0.9594        0.1302  3.9685
#       4        0.2984       0.9546        0.1595  3.9719
#       5        0.2892       0.9623        0.1228  4.0358
#       6        0.2808       0.9616        0.1253  3.8600
#       7        0.2781       0.9627        0.1269  3.6764
#       8        0.2812       0.9514        0.1720  3.7493
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=5; total time=  34.3s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5612       0.9449        0.1859  3.9081
#       2        0.3228       0.9510        0.1664  3.8828
#       3        0.2757       0.9591        0.1436  3.9157
#       4        0.2700       0.9587        0.1370  3.8874
#       5        0.2551       0.9590        0.1438  3.7137
#       6        0.2630       0.9619        0.1311  3.6781
#       7        0.2593       0.9604        0.1414  4.1072
#       8        0.2548       0.9630        0.1297  4.0798
# [CV] END batch_size=64, max_epochs=8, module__conv1_out_channels=5; total time=  33.9s
# conv1_out_channels: 20
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        2.3097       0.1044        2.3019  4.9477
#       2        1.7240       0.8972        0.3417  5.1087
# ...
# -------  ------------  -----------  ------------  ------
#       1        0.9574       0.9436        0.2173  5.9050
#       2        0.5509       0.9484        0.2020  6.2768
#       3        0.4729       0.9564        0.1710  6.2191
#       4        0.3884       0.9534        0.1579  6.2382
#       5        0.3280       0.9641        0.1276  6.2421
#       6        0.2813       0.9710        0.1028  6.2111
#       7        0.2662       0.9718        0.0981  6.1112
#       8        0.2433       0.9742        0.0918  6.1867
#       9        0.2462       0.9758        0.0854  6.0688
#      10        0.2296       0.9760        0.0900  6.0134
# [CV] END batch_size=160, max_epochs=10, module__conv1_out_channels=20; total time= 1.1min
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.7335       0.9349        0.2111  3.0753
#       2        0.4007       0.9505        0.1734  3.1202
#       3        0.3386       0.9434        0.1730  3.1795
#       4        0.3032       0.9483        0.1550  3.2117
#       5        0.2899       0.9597        0.1296  3.2279
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=5; total time=  18.6s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5765       0.9530        0.1608  3.0415
#       2        0.2832       0.9641        0.1219  3.0972
#       3        0.2248       0.9700        0.1023  3.2377
#       4        0.2008       0.9739        0.0895  3.2407
#       5        0.1909       0.9759        0.0898  3.2366
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=5; total time=  18.5s
# conv1_out_channels: 5
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6499       0.9473        0.1755  3.0768
#       2        0.3340       0.9514        0.1637  3.2574
#       3        0.2805       0.9634        0.1221  3.3100
#       4        0.2518       0.9671        0.1095  3.2929
#       5        0.2304       0.9670        0.1129  3.2967
# [CV] END batch_size=224, max_epochs=5, module__conv1_out_channels=5; total time=  18.9s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6689       0.9471        0.1707  4.9503
#       2        0.3384       0.9583        0.1364  5.1031
#       3        0.3002       0.9519        0.1524  5.1378
#       4        0.2697       0.9606        0.1353  5.2516
#       5        0.2594       0.9581        0.1478  5.2509
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=10; total time=  28.8s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4274       0.9536        0.1673  4.9150
#       2        0.2320       0.9679        0.1208  5.6777
#       3        0.2040       0.9677        0.1161  4.8625
#       4        0.1964       0.9593        0.1404  5.1217
#       5        0.2020       0.9695        0.1070  4.9945
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=10; total time=  28.7s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4843       0.9410        0.2020  4.9247
#       2        0.2884       0.9624        0.1237  5.0417
#       3        0.2566       0.9666        0.1272  5.0772
#       4        0.2398       0.9651        0.1263  5.2461
#       5        0.2227       0.9650        0.1228  5.9879
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=10; total time=  29.5s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4823       0.9604        0.1302  4.2724
#       2        0.2190       0.9666        0.1075  4.5081
#       3        0.1758       0.9725        0.0904  4.5222
#       4        0.1619       0.9680        0.1037  4.9351
#       5        0.1597       0.9760        0.0843  4.4371
#       6        0.1546       0.9759        0.0798  4.5191
#       7        0.1391       0.9731        0.0963  4.5408
#       8        0.1419       0.9755        0.0846  4.5393
# [CV] END batch_size=128, max_epochs=8, module__conv1_out_channels=10; total time=  39.4s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4120       0.9690        0.1123  4.3069
#       2        0.1866       0.9675        0.1232  4.5079
#       3        0.1600       0.9730        0.1056  4.5789
#       4        0.1414       0.9766        0.0801  4.5915
#       5        0.1389       0.9762        0.0843  4.5665
#       6        0.1289       0.9755        0.0886  4.6239
#       7        0.1345       0.9791        0.0794  4.5968
#       8        0.1264       0.9754        0.0857  4.6671
# [CV] END batch_size=128, max_epochs=8, module__conv1_out_channels=10; total time=  39.5s
# conv1_out_channels: 10
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5945       0.9370        0.2126  4.5564
#       2        0.3022       0.9571        0.1458  4.6980
#       3        0.2530       0.9666        0.1198  4.7180
#       4        0.2377       0.9701        0.1065  4.7736
#       5        0.2122       0.9714        0.1027  4.7569
#       6        0.2057       0.9665        0.1124  4.8824
#       7        0.2085       0.9718        0.0979  4.8649
#       8        0.2010       0.9778        0.0822  4.9651
# [CV] END batch_size=128, max_epochs=8, module__conv1_out_channels=10; total time=  41.3s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5680       0.9235        0.2413  6.2613
#       2        0.2802       0.9563        0.1412  6.4743
#       3        0.2527       0.9387        0.2067  6.4747
#       4        0.2339       0.9621        0.1307  6.5227
#       5        0.2222       0.9656        0.1214  6.6259
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=15; total time=  35.9s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5936       0.9384        0.2039  6.5348
#       2        0.3727       0.9579        0.1424  6.8116
#       3        0.3121       0.9629        0.1323  6.7454
#       4        0.2653       0.9645        0.1175  6.5149
#       5        0.2266       0.9529        0.1598  6.5286
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=15; total time=  36.7s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.3511       0.9589        0.1371  6.1302
#       2        0.2027       0.9718        0.1055  6.4261
#       3        0.1732       0.9705        0.1057  6.3909
#       4        0.1799       0.9669        0.1266  6.4022
#       5        0.1669       0.9667        0.1204  6.3266
# [CV] END batch_size=64, max_epochs=5, module__conv1_out_channels=15; total time=  35.1s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4979       0.9534        0.1653  4.9521
#       2        0.2062       0.9698        0.0999  5.1850
#       3        0.1685       0.9677        0.1027  5.0225
#       4        0.1515       0.9738        0.0891  4.9943
#       5        0.1373       0.9746        0.0859  5.0034
#       6        0.1312       0.9760        0.0868  4.9161
#       7        0.1260       0.9791        0.0780  4.9747
#       8        0.1155       0.9810        0.0664  4.8561
#       9        0.1218       0.9764        0.0841  4.8724
#      10        0.1143       0.9805        0.0671  4.8922
#      11        0.1075       0.9806        0.0626  4.9177
#      12        0.1036       0.9804        0.0698  4.7750
# [CV] END batch_size=224, max_epochs=12, module__conv1_out_channels=15; total time= 1.0min
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.4609       0.9667        0.1094  4.5345
#       2        0.1810       0.9740        0.0849  4.7055
#       3        0.1498       0.9761        0.0818  4.7289
#       4        0.1406       0.9762        0.0850  4.7520
#       5        0.1298       0.9812        0.0705  4.7554
#       6        0.1279       0.9805        0.0721  4.7550
#       7        0.1153       0.9824        0.0682  4.7726
#       8        0.1145       0.9786        0.0814  4.7139
#       9        0.1225       0.9808        0.0715  4.6755
#      10        0.1021       0.9774        0.0829  4.7318
#      11        0.1004       0.9828        0.0705  4.6943
#      12        0.1093       0.9824        0.0690  4.7232
# [CV] END batch_size=224, max_epochs=12, module__conv1_out_channels=15; total time=  59.6s
# conv1_out_channels: 15
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6881       0.9516        0.1529  4.5390
#       2        0.3139       0.9704        0.1018  4.7450
#       3        0.2538       0.9692        0.1018  4.7772
#       4        0.2224       0.9701        0.1008  4.8818
#       5        0.2117       0.9732        0.0840  4.9489
#       6        0.1976       0.9760        0.0815  4.9078
#       7        0.1920       0.9754        0.0886  4.8974
#       8        0.1824       0.9758        0.0814  4.8054
#       9        0.1722       0.9788        0.0772  4.8741
#      10        0.1754       0.9795        0.0715  4.9848
#      11        0.1656       0.9782        0.0718  4.9686
#      12        0.1560       0.9750        0.0856  4.9827
# [CV] END batch_size=224, max_epochs=12, module__conv1_out_channels=15; total time= 1.0min
# conv1_out_channels: 20
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.9301       0.9367        0.2109  6.0572
#       2        0.4286       0.9429        0.1770  6.3162
#       3        0.3691       0.9600        0.1246  6.2877
#       4        0.3570       0.9513        0.1512  6.2688
#       5        0.3346       0.9629        0.1234  6.3153
#       6        0.3272       0.9647        0.1098  6.3037
#       7        0.3333       0.9669        0.1089  6.3496
#       8        0.3067       0.9633        0.1103  6.3810
# [CV] END batch_size=160, max_epochs=8, module__conv1_out_channels=20; total time=  53.9s
# conv1_out_channels: 20
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.6776       0.9511        0.1600  6.3435
#       2        0.3481       0.9614        0.1244  6.6299
#       3        0.2974       0.9680        0.1114  6.6235
#       4        0.2587       0.9680        0.1080  6.5759
#       5        0.2366       0.9710        0.0990  6.5389
#       6        0.2194       0.9718        0.0988  6.5666
#       7        0.2067       0.9718        0.0968  6.4569
#       8        0.2030       0.9765        0.0863  6.3517
# [CV] END batch_size=160, max_epochs=8, module__conv1_out_channels=20; total time=  55.7s
# conv1_out_channels: 20
#   epoch    train_loss    valid_acc    valid_loss     dur
# -------  ------------  -----------  ------------  ------
#       1        0.5812       0.9605        0.1378  5.9133
#       2        0.2940       0.9657        0.1155  6.2484
#       3        0.2479       0.9722        0.1020  6.2349
#       4        0.2214       0.9741        0.0947  6.2094
#       5        0.2048       0.9756        0.0849  6.0773
#       6        0.2063       0.9780        0.0765  6.1061
#       7        0.1872       0.9749        0.0870  6.2267
#       8        0.1881       0.9772        0.0822  6.1373
# [CV] END batch_size=160, max_epochs=8, module__conv1_out_channels=20; total time=  52.6s
# best score: 0.979, best params: {'module__conv1_out_channels': 15, 'max_epochs': 12, 'batch_size': 224}
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 1 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/skorch/classifier.py", line 141, in fit
#     return super(NeuralNetClassifier, self).fit(X, y, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/skorch/net.py", line 1215, in fit
#     self.partial_fit(X, y, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/skorch/net.py", line 1174, in partial_fit
#     self.fit_loop(X, y, **fit_params)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/skorch/net.py", line 1087, in fit_loop
#     self.run_single_epoch(dataset_train, training=True, prefix="train",
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/skorch/net.py", line 1120, in run_single_epoch
#     for batch in self.get_iterator(dataset, training=training):
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 530, in __next__
#     data = self._next_data()
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1196, in _next_data
#     self._shutdown_workers()
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1322, in _shutdown_workers
#     w.join(timeout=_utils.MP_STATUS_CHECK_INTERVAL)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/multiprocessing/popen_fork.py", line 40, in wait
#     if not wait([self.sentinel], timeout):
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/multiprocessing/connection.py", line 936, in wait
#     ready = selector.select(timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/selectors.py", line 416, in select
#     fd_event_list = self._selector.poll(timeout)
#   File "/opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 33658) is killed by signal: Segmentation fault: 11.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.9/site-packages/sklearn/model_selection/_search.py:953: UserWarning: One or more of the test scores are non-finite: [0.97416667 0.9507     0.95676667 0.97393333 0.9709     0.97106667
#  0.96908333 0.96378333 0.97376667 0.9784     0.97573333 0.97045
#  0.97295    0.97335    0.97075    0.9643     0.96141667 0.97466667
#  0.97526667 0.95915    0.9686     0.976      0.95788333 0.97613333
#  0.68268333 0.97761667 0.97508333 0.95331667 0.97095    0.97561667
#         nan 0.9771     0.9655     0.68633333 0.97483333 0.97146667
#  0.68728333 0.95991667 0.97051667 0.97696667 0.97561667 0.97463333
#  0.97615    0.97131667 0.9658     0.96193333 0.97531667 0.9624
#  0.97923333 0.97191667]
#   warnings.warn(
